# %%
import asyncio
from playwright.async_api import async_playwright
import nest_asyncio
import json # To print results nicely

# Apply nest_asyncio for Jupyter compatibility
nest_asyncio.apply()

# --- Configuration ---
LONDON_URL = "https://en.uhomes.com/uk/london/imperial-college-london-icl/u96a1-sorta2"

# Pop-up Selectors (Working!)
COOKIE_ALLOW_SELECTOR = 'div.consent_button.all_action_button:has-text("Allow All")'
DREAM_HOME_CLOSE_SELECTOR = 'div.lead-form-dialog div.close'
DREAM_HOME_CLOSE_SELECTOR = 'i.el-dialog__close.el-icon-close'

# <i class="el-dialog__close el-icon el-icon-close"></i>
# --- NEW: Scraping Selectors (Based on your HTML) ---
LISTING_SELECTOR = 'a.house-card.list'
NAME_SELECTOR = 'h2.title'
ADDRESS_SELECTOR = 'div.location'
PRICE_SELECTOR = 'span.current-price'
AMENITIES_SELECTOR = 'div.tags-box span.item'
# ---------------------------------------------------

print("Libraries imported. All pop-up and scraping selectors defined.")
# Out:
# Libraries imported. All pop-up and scraping selectors defined.

# %%
async def scrape_london_uhomes():
    """
    Opens uhomes.com, handles pop-ups, and scrapes listing data.
    """
    print("Starting Playwright...")
    scraped_data = [] # List to hold our results
    p = await async_playwright().start()
    browser = await p.chromium.launch(headless=False) # Keep visible for now
    page = await browser.new_page()
    print(f"Playwright started. Navigating to {LONDON_URL}...")

    try:
        # Go to the page
        await page.goto(LONDON_URL, wait_until="networkidle", timeout=60000) # Wait for network idle
        print("Page loaded. Waiting 3 seconds...")
        await page.wait_for_timeout(3000)

        # --- 1. Attempt to click the cookie banner (FIRST) ---
        try:
            print(f"  - Looking for cookie banner: {COOKIE_ALLOW_SELECTOR}")
            await page.locator(COOKIE_ALLOW_SELECTOR).click(timeout=7000)
            print("  - Clicked cookie banner.")
            await page.wait_for_timeout(1000)
        except Exception as e:
            print(f"  - Could not click cookie banner: {type(e).__name__}")
        # ----------------------------------------

        # --- 2. Attempt to close 'Dream Home' Pop-up (SECOND) ---
        try:
            print(f"  - Looking for Dream Home close button: {DREAM_HOME_CLOSE_SELECTOR}")
            await page.locator(DREAM_HOME_CLOSE_SELECTOR).click(timeout=10*7000)
            print("  - Clicked 'Dream Home' close button.")
            await page.wait_for_timeout(1000)
        except Exception as e:
            print(f"  - Could not click 'Dream Home' close button: {type(e).__name__}")
        # ----------------------------------------

        print("\nPop-up handling done. Starting scraping...")
        await page.wait_for_timeout(3000) # Final wait before scraping

        # --- 3. Scrape the listings ---
        print(f"Looking for listings with selector: {LISTING_SELECTOR}")
        await page.wait_for_selector(LISTING_SELECTOR, timeout=20000)
        listings = await page.locator(LISTING_SELECTOR).all()
        print(f"Found {len(listings)} listings on this page.")

        for i, listing in enumerate(listings):
            print(f"  - Processing listing {i+1}...")
            try:
                name = await listing.locator(NAME_SELECTOR).text_content(timeout=2000)
                address = await listing.locator(ADDRESS_SELECTOR).text_content(timeout=2000)
                price = await listing.locator(PRICE_SELECTOR).text_content(timeout=2000)
                link = await listing.get_attribute('href')
                
                # Get all amenities - this returns a list of strings
                amenity_elements = await listing.locator(AMENITIES_SELECTOR).all()
                amenities = [await amenity.text_content() for amenity in amenity_elements]
                # Clean up amenities (remove empty strings, strip whitespace)
                amenities = [a.strip() for a in amenities if a and a.strip()]

                # Build the full URL for the link
                full_link = f"https://en.uhomes.com{link}" if link and link.startswith('/') else link

                scraped_data.append({
                    "name": name.strip() if name else "N/A",
                    "address": address.strip() if address else "N/A",
                    "price_per_week": price.strip() if price else "N/A",
                    "amenities": amenities,
                    "link": full_link
                })
                print(f"    -> Scraped: {name.strip() if name else 'N/A'}")

            except Exception as e:
                print(f"    -> FAILED to process listing {i+1}: {e}")
            
            await page.wait_for_timeout(50) # Tiny delay between listings

        # -----------------------------

    except Exception as e:
        print(f"An major error occurred during scraping: {e}")
        await page.screenshot(path="scraping_error_screenshot.png")
        print("Saved screenshot to scraping_error_screenshot.png")

    finally:
        # Ensure the browser is always closed
        print("Closing browser...")
        await browser.close()
        await p.stop()
        print("Browser closed.")

    # --- *** NEW: Save the data to a JSON file *** ---
    if scraped_data:
        try:
            with open('uhomes_data.json', 'w', encoding='utf-8') as f:
                json.dump(scraped_data, f, ensure_ascii=False, indent=4)
            print(f"Successfully saved {len(scraped_data)} listings to uhomes_data.json")
        except Exception as e:
            print(f"Error saving data to JSON: {e}")
    else:
        print("No data was scraped, so no file was saved.")
    # --- *** End of New Code *** ---

    return scraped_data # Still return the data

# %%
import pandas as pd

# %%
pd.DataFrame(all_scraped_data)
# Out:
#                               name  \
# 0      Canvas Student Arthur House
# 1                 Chapter Lewisham
# 2            Chapter London Bridge
# 3                          iQ Vega
# 4            HL-Skyline Apartments
# 5   Vita Student Lewisham Exchange
# 6                 Downing The Lyra
# 7                Scape Hammersmith
# 8                Portchester House
# 9                Emily Bowes Court
# 10                Scape Bloomsbury
# 11                 Ferrum Building
#
#                                               address price_per_week  \
# 0    1 Rutherford Way, London HA9 0BP, United Kingdom           £349
# 1   46 Thurston Road, London SE13 7SD, United Kingdom           £308
# 2   48-50 Weston Street, London SE1 3QJ, United Ki...           £493
# 3   6 Miles Street Vauxhall, London SW8 1RZ, Unite...           £422
# 4       11 Makers Yard, London E3 3JX, United Kingdom        £578.02
# 5   Exchange Point, Loampit Vale, London SE13 7NX,...           £355
# 6          North Acton, London W3 6BX, United Kingdom           £343
# 7        Talgarth Road, London W6 8DN, United Kingdom           £403
# 8    50 New Kent Road, London SE1 6SH, United Kingdom        £441.02
# 9      6 Lebus Street, London N17 9FD, United Kingdom           £272
# 10  19-29 Woburn Place, London WC1H 0AQ, United Ki...        £344.02
# 11  40 South Way, Wembley Park, London HA9 0HZ, Un...         £2,003
#
#                                             amenities  \
# 0   [ Verified,  Student Accommodation, Parcels ...
# 1   [ Verified,  Student Accommodation, Free reg...
# 2   [ Verified,  Student Accommodation, Sky Gard...
# 3   [ Verified,  Student Accommodation, Live wit...
# 4            [ Apartment, Parcels collect, Elevator]
# 5   [ Verified,  Student Accommodation, Breakfas...
# 6   [ Verified,  Student Accommodation, "Operato...
# 7   [ Verified,  Student Accommodation, with air...
# 8   [ Verified,  Student Accommodation, Parcels ...
# 9   [ Verified,  Student Accommodation, Near Sub...
# 10  [ Verified,  Student Accommodation, Near bus...
# 11  [ Verified,  Apartment, Pets friendly, City ...
#
#                                                  link
# 0   https://en.uhomes.com/uk/london/detail-apartme...
# 1   https://en.uhomes.com/uk/london/detail-apartme...
# 2   https://en.uhomes.com/uk/london/detail-apartme...
# 3   https://en.uhomes.com/uk/london/detail-apartme...
# 4   https://en.uhomes.com/uk/london/detail-apartme...
# 5   https://en.uhomes.com/uk/london/detail-apartme...
# 6   https://en.uhomes.com/uk/london/detail-apartme...
# 7   https://en.uhomes.com/uk/london/detail-apartme...
# 8   https://en.uhomes.com/uk/london/detail-apartme...
# 9   https://en.uhomes.com/uk/london/detail-apartme...
# 10  https://en.uhomes.com/uk/london/detail-apartme...
# 11  https://en.uhomes.com/uk/london/detail-apartme...

# %%
# Run the full function
print("Executing the full scraping script...")
all_scraped_data = await scrape_london_uhomes()
print("\n--- Scraping Finished ---")

# Print the results in a readable format
print(f"Total listings scraped: {len(all_scraped_data)}\n")
print("--- First 5 Results ---")
print(json.dumps(all_scraped_data[:5], indent=2)) # Using json for pretty printing
print("-----------------------")

# You can now use 'all_scraped_data' (which is a list of dictionaries)
# for your real-time tracking application (e.g., save to a database, compare prices).
# Out:
# Executing the full scraping script...
# Starting Playwright...
# Playwright started. Navigating to https://en.uhomes.com/uk/london/imperial-college-london-icl...
# Page loaded. Waiting 3 seconds...
#   - Looking for cookie banner: div.consent_button.all_action_button:has-text("Allow All")
#   - Clicked cookie banner.
#   - Looking for Dream Home close button: div.lead-form-dialog div.close
#   - Could not click 'Dream Home' close button: TimeoutError
#
# Pop-up handling done. Starting scraping...
# Looking for listings with selector: a.house-card.list
# Found 12 listings on this page.
#   - Processing listing 1...
#     -> Scraped: Fifty One London
#   - Processing listing 2...
#     -> Scraped: Downing The Lyra
#   - Processing listing 3...
#     -> Scraped: Chapter Ealing
#   - Processing listing 4...
#     -> Scraped: iQ Hammersmith
#   - Processing listing 5...
#     -> Scraped: Chelsea Lightfoot Hall
#   - Processing listing 6...
#     -> Scraped: Scape Hammersmith
#   - Processing listing 7...
#     -> Scraped: Chapter Portobello
#   - Processing listing 8...
#     -> Scraped: Chapter White City
#   - Processing listing 9...
#     -> Scraped: Dolphin Square
#   - Processing listing 10...
#     -> Scraped: Ravenscourt House
#   - Processing listing 11...
#     -> Scraped: Spring Mews
#   - Processing listing 12...
#     -> Scraped: County Hall Apartment
# Closing browser...
# Browser closed.
#
# --- Scraping Finished ---
# Total listings scraped: 12
#
# --- First 5 Results ---
# [
#   {
#     "name": "Fifty One London",
#     "address": "Cromwell Road, London SW7 2EH, United Kingdom",
#     "price_per_week": "\u00a3828",
#     "amenities": [
#       "\ue898 Verified",
#       "\ue907 Student Accommodation",
#       "Free regular cleaning",
#       "Bills included",
#       "Furnished",
#       "Brand new",
#       "Parcels collect",
#       "CINEMA",
#       "Double Occupancy(Free)",
#       "Elevator"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-1655401?schoolunique=imperial-college-london-icl"
#   },
#   {
#     "name": "Downing The Lyra",
#     "address": "North Acton, London W3 6BX, United Kingdom",
#     "price_per_week": "\u00a3343",
#     "amenities": [
#       "\ue898 Verified",
#       "\ue907 Student Accommodation",
#       "\"Operator of the Year\"",
#       "Parcels collect",
#       "Bills included",
#       "Near railway station",
#       "Near bus station",
#       "Elevator",
#       "with air-con",
#       "Short lease"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-13352?schoolunique=imperial-college-london-icl"
#   },
#   {
#     "name": "Chapter Ealing",
#     "address": "Victoria Road, London W3 6UN, United Kingdom",
#     "price_per_week": "\u00a3345",
#     "amenities": [
#       "\ue898 Verified",
#       "\ue907 Student Accommodation",
#       "No Deposit",
#       "Free regular cleaning",
#       "Near Subway",
#       "Near supermarket",
#       "Near bus station",
#       "Parcels collect",
#       "Bills included",
#       "Gym",
#       "Elevator"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-793913?schoolunique=imperial-college-london-icl"
#   },
#   {
#     "name": "iQ Hammersmith",
#     "address": "230 Shepherds Bush Road, London W6 7NL, United Kingdom",
#     "price_per_week": "\u00a3435",
#     "amenities": [
#       "\ue898 Verified",
#       "\ue907 Student Accommodation",
#       "Referral Bonus",
#       "25/26 AY Cladding work",
#       "Near Subway",
#       "Near supermarket",
#       "Near bus station",
#       "Double Occupancy(Free)",
#       "Short lease",
#       "Parcels collect"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-13897?schoolunique=imperial-college-london-icl"
#   },
#   {
#     "name": "Chelsea Lightfoot Hall",
#     "address": "Manresa Road, London SW3 6NA, United Kingdom",
#     "price_per_week": "\u00a3218.02",
#     "amenities": [
#       "\ue898 Verified",
#       "\ue907 Student Accommodation",
#       "Walk to school",
#       "Near bus station",
#       "Parcels collect",
#       "Bills included",
#       "24 hours security",
#       "Elevator"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-29064?schoolunique=imperial-college-london-icl"
#   }
# ]
# -----------------------

# %%
pd.DataFrame(all_scraped_data)
# Out:
#                       name                                            address  \
# 0         Fifty One London      Cromwell Road, London SW7 2EH, United Kingdom
# 1         Downing The Lyra         North Acton, London W3 6BX, United Kingdom
# 2           Chapter Ealing       Victoria Road, London W3 6UN, United Kingdom
# 3           iQ Hammersmith  230 Shepherds Bush Road, London W6 7NL, United...
# 4   Chelsea Lightfoot Hall       Manresa Road, London SW3 6NA, United Kingdom
# 5        Scape Hammersmith       Talgarth Road, London W6 8DN, United Kingdom
# 6       Chapter Portobello  1 Alderson Street, London W10 5JY, United Kingdom
# 7       Chapter White City  10 Westway Shepherd's Bush, London W12 0DD, Un...
# 8           Dolphin Square  Chichester Street, London SW1V 3LX, United Kin...
# 9        Ravenscourt House    3 Paddenswick Rd, London W6 0BY, United Kingdom
# 10             Spring Mews    10 Tinworth St, London SE11 5AL, United Kingdom
# 11   County Hall Apartment       Belvedere Rd, London SE1 7GP, United Kingdom
#
#    price_per_week                                          amenities  \
# 0            £828  [ Verified,  Student Accommodation, Free reg...
# 1            £343  [ Verified,  Student Accommodation, "Operato...
# 2            £345  [ Verified,  Student Accommodation, No Depos...
# 3            £435  [ Verified,  Student Accommodation, Referral...
# 4         £218.02  [ Verified,  Student Accommodation, Walk to ...
# 5            £403  [ Verified,  Student Accommodation, with air...
# 6            £307  [ Verified,  Student Accommodation, No Depos...
# 7            £397  [ Verified,  Student Accommodation, No Depos...
# 8          £1,909  [ Verified,  Apartment, Walk to school, Doub...
# 9         £349.41  [ Verified,  Student Accommodation, Bills in...
# 10           £398  [ Verified,  Student Accommodation, Swimming...
# 11           £375  [ Verified,  Apartment, Parcels collect, Wee...
#
#                                                  link
# 0   https://en.uhomes.com/uk/london/detail-apartme...
# 9   https://en.uhomes.com/uk/london/detail-apartme...
# 10  https://en.uhomes.com/uk/london/detail-apartme...
# 11  https://en.uhomes.com/uk/london/detail-apartme...

# %%
# Run the full function
print("Executing the full scraping script...")
all_scraped_data = await scrape_london_uhomes()
print("\n--- Scraping Finished ---")

# Print the results in a readable format
print(f"Total listings scraped: {len(all_scraped_data)}\n")
print("--- First 5 Results ---")
print(json.dumps(all_scraped_data[:5], indent=2)) # Using json for pretty printing
print("-----------------------")

# You can now use 'all_scraped_data' (which is a list of dictionaries)
# for your real-time tracking application (e.g., save to a database, compare prices).
# Out:
# Executing the full scraping script...
# Starting Playwright...
# Playwright started. Navigating to https://en.uhomes.com/uk/london/imperial-college-london-icl/u96a1-sorta2...
# Page loaded. Waiting 3 seconds...
#   - Looking for cookie banner: div.consent_button.all_action_button:has-text("Allow All")
#   - Clicked cookie banner.
#   - Looking for Dream Home close button: i.el-dialog__close.el-icon-close
#   - Could not click 'Dream Home' close button: TimeoutError
#
# Pop-up handling done. Starting scraping...
# Looking for listings with selector: a.house-card.list
# Found 12 listings on this page.
#   - Processing listing 1...
#     -> Scraped: The Other House South Kensington
#   - Processing listing 2...
#     -> Scraped: Fifty One London
#   - Processing listing 3...
#     -> Scraped: Scape Kings Cross
#   - Processing listing 4...
#     -> Scraped: iQ Bloomsbury
#   - Processing listing 5...
#     -> Scraped: Gob Spitalfields Residence
#   - Processing listing 6...
#     -> Scraped: Lit Westminster Residence
#   - Processing listing 7...
#     -> Scraped: Gob Aldgate Residence
#   - Processing listing 8...
#     -> Scraped: Gob Westminster Residence
#   - Processing listing 9...
#     -> Scraped: Lit Old Street Residence
#   - Processing listing 10...
#     -> Scraped: Lit Spitalfields Residence
#   - Processing listing 11...
#     -> Scraped: Gob Kings Cross Residence
#   - Processing listing 12...
#     -> Scraped: Kirby Street Residence
# Closing browser...
# Browser closed.
# Successfully saved 12 listings to uhomes_data.json
#
# --- Scraping Finished ---
# Total listings scraped: 12
#
# --- First 5 Results ---
# [
#   {
#     "name": "The Other House South Kensington",
#     "address": "15-17 Harrington Gardens, South Kensington, London SW7 4JJ, United Kingdom",
#     "price_per_week": "\u00a31,050",
#     "amenities": [
#       "\ue907 Student Accommodation",
#       "Bills included",
#       "24 hours security",
#       "Gym",
#       "Parcels collect"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-1591606?schoolunique=imperial-college-london-icl"
#   },
#   {
#     "name": "Fifty One London",
#     "address": "Cromwell Road, London SW7 2EH, United Kingdom",
#     "price_per_week": "\u00a3828",
#     "amenities": [
#       "\ue898 Verified",
#       "\ue907 Student Accommodation",
#       "Free regular cleaning",
#       "Bills included",
#       "Furnished",
#       "Brand new",
#       "Parcels collect",
#       "CINEMA",
#       "Double Occupancy(Free)",
#       "Elevator"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-1655401?schoolunique=imperial-college-london-icl"
#   },
#   {
#     "name": "Scape Kings Cross",
#     "address": "30 Thanet Street, London WC1H 9QH, United Kingdom",
#     "price_per_week": "\u00a3689.02",
#     "amenities": [
#       "\ue898 Verified",
#       "\ue907 Student Accommodation",
#       "Near railway station",
#       "Walk to school",
#       "Near bus station",
#       "Parcels collect",
#       "Bills included",
#       "Elevator"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-1515952?schoolunique=imperial-college-london-icl"
#   },
#   {
#     "name": "iQ Bloomsbury",
#     "address": "200 Euston Road, London NW1 2FA, United Kingdom",
#     "price_per_week": "\u00a3666.02",
#     "amenities": [
#       "\ue898 Verified",
#       "\ue907 Student Accommodation",
#       "Referral Bonus",
#       "25/26 AY Cladding work",
#       "Double Occupancy(Free)",
#       "Parcels collect",
#       "Bills included",
#       "24 hours security",
#       "Near Subway",
#       "Near railway station"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-18399?schoolunique=imperial-college-london-icl"
#   },
#   {
#     "name": "Gob Spitalfields Residence",
#     "address": "9 Frying Pan Alley, London E1 7HS, United Kingdom",
#     "price_per_week": "\u00a3599",
#     "amenities": [
#       "\ue898 Verified",
#       "\ue907 Student Accommodation",
#       "Bills included",
#       "CINEMA",
#       "Short lease",
#       "Gym",
#       "Elevator",
#       "Parcels collect"
#     ],
#     "link": "https://en.uhomes.com/uk/london/detail-apartments-1499412?schoolunique=imperial-college-london-icl"
#   }
# ]
# -----------------------

# %%
# --- Load Data ---
# @st.cache_data # Cache the data loading for performance
def load_data(filepath='uhomes_data.json'):
    """Loads scraped data from a JSON file."""
    try:
        with open(filepath, 'r', encoding='utf-8') as f:
            data = json.load(f)
        df = pd.DataFrame(data)
        return df
    except FileNotFoundError:
    #     st.error(f"Error: The data file '{filepath}' was not found.")
    #     st.warning("Please run your scraper first to generate the uhomes_data.json file.")
    #     return None
    # except Exception as e:
    #     st.error(f"An error occurred while loading the data: {e}")
        return None

# %%
load_data()
# Out:
#                                 name  \
# 0   The Other House South Kensington
# 1                   Fifty One London
# 2                  Scape Kings Cross
# 3                      iQ Bloomsbury
# 4         Gob Spitalfields Residence
# 5          Lit Westminster Residence
# 6              Gob Aldgate Residence
# 7          Gob Westminster Residence
# 8           Lit Old Street Residence
# 9         Lit Spitalfields Residence
# 10         Gob Kings Cross Residence
# 11            Kirby Street Residence
#
#                                               address price_per_week  \
# 0   15-17 Harrington Gardens, South Kensington, Lo...         £1,050
# 1       Cromwell Road, London SW7 2EH, United Kingdom           £828
# 2   30 Thanet Street, London WC1H 9QH, United Kingdom        £689.02
# 3     200 Euston Road, London NW1 2FA, United Kingdom        £666.02
# 4   9 Frying Pan Alley, London E1 7HS, United Kingdom           £599
# 5   200A Lambeth Road, London SE1 7LR, United Kingdom           £590
# 6   1-2 Education Square, London E1 1FA, United Ki...           £580
# 7   200A Lambeth Road, London SE1 7LR, United Kingdom           £575
# 8     18 Paul Street, London EC2A 4JH, United Kingdom           £575
# 9   9 Frying Pan Alley, London E1 7HS, United Kingdom           £575
# 10  200 Pentonville Road, London N1 9JP, United Ki...           £565
# 11  36-43 Kirby Street, London EC1N 8TE, United Ki...           £564
#
#                                             amenities  \
# 0   [ Student Accommodation, Bills included, 24 h...
# 1   [ Verified,  Student Accommodation, Free reg...
# 2   [ Verified,  Student Accommodation, Near rai...
# 3   [ Verified,  Student Accommodation, Referral...
# 4   [ Verified,  Student Accommodation, Bills in...
# 5   [ Student Accommodation, No Deposit, Bills in...
# 6   [ Student Accommodation, Walk to school, 24 h...
# 7      [ Student Accommodation, Bills included, Gym]
# 8   [ Verified,  Student Accommodation, No Depos...
# 9   [ Verified,  Student Accommodation, No Depos...
# 10  [ Verified,  Student Accommodation, Bills in...
# 11  [ Verified,  Student Accommodation, Bills in...
#
#                                                  link
